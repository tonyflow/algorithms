# %%
import os

# %%
os.listdir('.')
# Out:
# ['path_sum.py',
#  'all_possible_words_in_a_phone_number.py',
#  'keys_and_rooms.py',
#  'binary_search.py',
#  'miscellaneous_niko.py',
#  'distribute_coins_in_binary_tree.py',
#  'merge_k_sorted_lists.py',
#  'graph_node.py',
#  'remove_duplicate_letters.py',
#  'all_nodes_distance_k_in_binary_tree.py',
#  'tree_node.py',
#  'evaluate_division.py',
#  'Untitled.ipynb',
#  'different_ways_to_add_parentheses.py',
#  'clone_graph.py',
#  'binary_tree_traversals.py',
#  'construct_string_from_binary_tree.py',
#  '__pycache__',
#  'search_in_rotated_array.py',
#  'kth_largest_element_in_an_array.py',
#  'list_node.py',
#  'coin_change.py',
#  'combination_sum_ii.py',
#  'remove_nth_node_from_the_end_of_list.py',
#  'kth_smallest_element_in_a_sorted_matrix.py',
#  'concurrency',
#  'ethonai.py',
#  'trie',
#  'callables_test.py',
#  'construct_binary_tree_from_pre_order_and_post_order_traversal.py',
#  'copy_list_with_random_pointer.py',
#  'longest_increasing_subsequence.py',
# ...
